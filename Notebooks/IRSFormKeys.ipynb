# %% [markdown]
# # IRS PDF Form Build Keys
#
# ------------------
# ## form1065_filler.py
# Python class that fills an IRS Form 1065 PDF (U.S. Return of Partnership Income)
# from a plain Python dict.
#
#
# ## Workflow: FormKey Mapping
#
# #### A. Gen Key Maps (irs.irsForms)
#
# 1. genTestKeyDict
#     - irsForm -> fldDict [Field Dict]
#     - iraForm -> testDict
#     - OUT:
#         - testDict
#         - FILE: pdfFill(testDict) -> irsForms/<fm>-IRS.pdf.  [visual of forms with F#]
# 5. genIRSMap
#     - fldDict -> keyDict -> irsForms/<fm>-IRS.json [map <fldName> -> F# ]
#
# #### B. Gen IRS Report (irs.pdfFill)
#
# 1. gen_glTaxDict
#     - glDict -> glKeys. [ Core of IRS Tax mapping]
#     - glDict X glKeys -> glTaxDict -> irsForms/<fm>_glKey.json [<fldName -> glDict.alues]
#     - glTaxDict X keyDict -> fmDict  [form values: fmKey -> glDict.values]
# 1. FILE: pdfFill(fmDict) ->  YE_Tax_Report/<fm>-IRS.pdf
#
# ------
# ## Build Key
#
# - input IRS_Forms/formFN.pdf
# - get all fields into Dict
# - save

# %%
# Load bookkeeping services : llc, coa, 
import os
from ledger.LLC import LLC
from pathlib import Path
import datetime
import pandas as pd
import numpy as np
from IPython.display import display, Markdown

from ledger.llcCOA import ChartOfAccounts
from util.utilEditSession import utilEditSession
import pandas as pd



top = Path.cwd().parents[2]
llc = LLC('WBGroupLLC',debug=False, top=top)  # debug='details'
# Load Latest/YE Bank Stmt
llc._Bank()
# Chart of accounts
coa = ChartOfAccounts(llc)
# Edit Session

# %%
# ── 1. Instantiate ────────────────────────────────────────────────
#    Option A: pass an LLC object (derives irsDir automatically)
#    f1065 = Form1065(llc=llc)
#
#    Option B: no llc — uses fallback path from __file__ location


from irs.Form1065 import Form1065
f1065 = Form1065(llc, verbose=False)
fillDict_1065 = f1065._to_PDF(testField='f20')

from irs.Sch_K1 import Sch_K1
fschk1 = Sch_K1(llc, verbose=False)
fillDict_SchK1 = fschk1._to_PDF()

from irs.Form4562 import Form4562
f4562 = Form4562(llc, verbose=False)
fillDict_4562 = f4562._to_PDF()
# Out:
# irsForm Entry: oID:Form1065, verbose:False
# irsForm.Form1065 _to_PDF Entry
# Form1065 buildFillDict Entry verbose:False, testField:f20
# irsForm.Form1065 buildFillDict Entry
# WARNING: No YR.2025.Beg.Cash in llcAsset DB,acct = Acct.Cash.Balance. -- default to 0.0
# Acct.Rev List: 12, revList:7
# Acct.Rev List: 12, revList:7
#
#   → /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Form1065_FILL.pdf
# irsForm Entry: oID:Sch_K1, verbose:False
# irsForm.Sch_K1 _to_PDF Entry
# irsForm.Sch_K1 buildFillDict Entry
# WARNING: No YR.2025.Beg.Cash in llcAsset DB,acct = Acct.Cash.Balance. -- default to 0.0
# Acct.Rev List: 12, revList:7
# Acct.Rev List: 12, revList:7
#
#   → /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Sch_K1_FILL.pdf
# irsForm Entry: oID:Form4562, verbose:False
# irsForm.Form4562 _to_PDF Entry
# irsForm.Form4562 buildFillDict Entry
# WARNING: No YR.2025.Beg.Cash in llcAsset DB,acct = Acct.Cash.Balance. -- default to 0.0
# Acct.Rev List: 12, revList:7
# Acct.Rev List: 12, revList:7
#
#   → /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Form4562_FILL.pdf

# %%
# display PDF frame
import base64
from IPython.display import IFrame

class pdfFrame:

    def pdfDisplay(self, fn):

        lFN = '_junk.pdf'
    
        # Copy pdf to local foldere
        shutil.copy(str(fn), lFN)
        
        # Replace 'your_document.pdf' with the path to your file
        frm = IFrame(str(lFN), width=800, height=500)
    
        Path(lFN).unlink(missing_ok=True)
    
        return frm



    def pdfHTML(self, fn):
        with open(str(fn), "rb") as f:
            # Read file and encode to base64
            base64_pdf = base64.b64encode(f.read()).decode('utf-8')
        
        # Create an embedded PDF viewer string
        pdf_display = f'<iframe src="data:application/pdf;base64,{base64_pdf}" width="800" height="500" type="application/pdf"></iframe>'
        
        from IPython.core.display import HTML
        return HTML(pdf_display)

# %%
pf = pdfFrame()
display(pf.pdfHTML(f1065._fillFN()))
# Out:
# <iframe src="data:application/pdf;base64,..." width="800" height="500" type="application/pdf"></iframe>

# %%
fillDict = f1065.nSpaceMap()
# Out:
# Form1065 buildFillDict Entry verbose:False, testField:None
# irsForm.Form1065 buildFillDict Entry
# WARNING: No YR.2025.Beg.Cash in llcAsset DB,acct = Acct.Cash.Balance. -- default to 0.0
# Acct.Rev List: 12, revList:7
# Acct.Rev List: 12, revList:7

# %%
#pd.DataFrame(fillDict).transpose()
fillDict
# Out:
# {('IncomeStmt',
#   'TOTAL',
#   'Balance'): [{'formNm': 'Form1065',
#    'logicalKey': 'P1_23',
#    'fID': '',
#    'pdfField': '',
#    'shortName': '',
#    'label': '',
#    'fType': 'text',
#    'page': 0,
#    'location': '',
#    'checkedValue': '',
#    'publish': True,
#    'value': '-2,770.47',
#    'raw': -2770.47,
#    'note': 'Pg1 L23 — Ordinary business income (loss)',
#    'src_tbl': 'IncomeStmt',
#    'src_row': 'TOTAL',
#    'src_col': 'Balance'}, {'formNm': 'Form1065',
#    'logicalKey': 'K_1',
#    'fID': '',
#    'pdfField': '',
#    'shortName': '',
#    'label': '',
#    'fType': 'text',
#    'page': 0,
#    'location': '',
#    'checkedValue': '',
#    'publish': True,
#    'value': '-2,770.47',
#    'raw': -2770.47,
#    'note': 'Sched K L1 — Ordinary business income',
#    'src_tbl': 'IncomeStmt',
#    'src_row': 'TOTAL',
#    'src_col': 'Balance'}, {'formNm': 'Form1065',
#    'logicalKey': 'M1_1',
#    'fID': '',
#    'pdfField': '',
#    'shortName': '',
#    'label': '',
#    'fType': 'text',
#    'page': 0,
#    'location': '',
#    'checkedValue': '',
#    'publish': True,
#    'value': '-2,770.47',
#    'raw': -2770.47,
#    'note': 'Sched M-1 L1 — Net income (loss) per books',
#    'src_tbl': 'IncomeStmt',
#    'src_row': 'TOTAL',
#    'src_col': 'Balance'}, {'formNm': 'Form1065',
#    'logicalKey': 'M1_5',
#    'fID': '',
#    'pdfField': '',
#    'shortName': '',
#    'label': '',
#    'fType': 'text',
#    'page': 0,
#    'location': '',
#    'checkedValue': '',
#    'publish': True,
#    'value': '-2,770.47',
#    'raw': -2770.47,
#    'note': 'Sched M-1 L5 subtotal (simplified)',
#    'src_tbl': 'IncomeStmt',
#    'src_row': 'TOTAL',
#    'src_col': 'Balance'}, {'formNm': 'Form1065',
#    'logicalKey': 'M1_9',
#    'fID': '',
#    'pdfField': '',
#    'shortName': '',
#    'label': '',
#    'fType': 'text',
#    'page': 0,
#    'location': '',
#    'checkedValue': '',
#    'publish': True,
#    'value': '-2,770.47',
#    'raw': -2770.47,
#    'note': 'Sched M-1 L9 — Income per return',
#    'src_tbl': 'IncomeStmt',
#    'src_row': 'TOTAL',
#    'src_col': 'Balance'}, {'formNm': 'Form1065',
#    'logicalKey': 'M2_3',
#    'fID': '',
#    'pdfField': '',
#    'shortName': '',
#    'label': '',
#    'fType': 'text',
#    'page': 0,
#    'location': '',
#    'checkedValue': '',
#    'publish': True,
#    'value': '-2,770.47',
#    'raw': -2770.47,
#    'note': 'Sched M-2 L3 — Net income per books',
#    'src_tbl': 'IncomeStmt',
#    'src_row': 'TOTAL',
#    'src_col': 'Balance'}],
#  ('OwnerEquity',
#   'TOTAL',
#   'Balance'): [{'formNm': 'Form1065',
#    'logicalKey': 'L_21_2',
#    'fID': '',
#    'pdfField': '',
#    'shortName': '',
#    'label': '',
#    'fType': 'text',
#    'page': 0,
#    'location': '',
#    'checkedValue': '',
#    'publish': True,
#    'value': '238,520.54',
#    'raw': 238520.54,
#    'note': "Sched L L21 col(d) — Partners' capital accts EOY",
#    'src_tbl': 'OwnerEquity',
#    'src_row': 'TOTAL',
#    'src_col': 'Balance'}, {'formNm': 'Form1065',
#    'logicalKey': 'M2_9',
#    'fID': '',
#    'pdfField': '',
#    'shortName': '',
#    'label': '',
#    'fType': 'text',
#    'page': 0,
#    'location': '',
#    'checkedValue': '',
#    'publish': True,
#    'value': '238,520.54',
#    'raw': 238520.54,
#    'note': 'Sched M-2 L9 — Balance at end of year',
#    'src_tbl': 'OwnerEquity',
#    'src_row': 'TOTAL',
#    'src_col': 'Balance'}]}

# %%
from stmt.stmtIncomeStmt import stmtIncomeStmt

objIS = stmtIncomeStmt(llc)
is_fDict = objIS.nSpaceMap()
is_fDict
# Out:
# {('IncomeStmt', 'Income.Acct.Rev.Fees.Other.Bank', '_lineNo'): 1,
#  ('IncomeStmt',
#   'Income.Acct.Rev.Fees.Other.Bank',
#   '_rowNm'): 'Income.Acct.Rev.Fees.Other.Bank',
#  ('IncomeStmt', 'Income.Acct.Rev.Fees.Other.Bank', 'acctType'): 'Income',
#  ('IncomeStmt',
#   'Income.Acct.Rev.Fees.Other.Bank',
#   'acct'): 'Acct.Rev.Fees.Other',
#  ('IncomeStmt', 'Income.Acct.Rev.Fees.Other.Bank', 'acctSub'): 'Bank',
#  ('IncomeStmt', 'Income.Acct.Rev.Fees.Other.Bank', 'Debit'): 0.53,
#  ('IncomeStmt', 'Income.Acct.Rev.Fees.Other.Bank', 'Credit'): 400.53,
#  ('IncomeStmt', 'Income.Acct.Rev.Fees.Other.Bank', 'Balance'): -400.0,
#  ('IncomeStmt', 'Income.Acct.Rev.Rent.Income.Rent', '_lineNo'): 2,
#  ('IncomeStmt',
#   'Income.Acct.Rev.Rent.Income.Rent',
#   '_rowNm'): 'Income.Acct.Rev.Rent.Income.Rent',
#  ('IncomeStmt', 'Income.Acct.Rev.Rent.Income.Rent', 'acctType'): 'Income',
#  ('IncomeStmt', 'Income.Acct.Rev.Rent.Income.Rent', 'acct'): 'Acct.Rev.Rent',
#  ('IncomeStmt', 'Income.Acct.Rev.Rent.Income.Rent', 'acctSub'): 'Income.Rent',
#  ('IncomeStmt', 'Income.Acct.Rev.Rent.Income.Rent', 'Debit'): 0.0,
#  ('IncomeStmt', 'Income.Acct.Rev.Rent.Income.Rent', 'Credit'): 4000.0,
#  ('IncomeStmt', 'Income.Acct.Rev.Rent.Income.Rent', 'Balance'): -4000.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Depreciation', '_lineNo'): 3,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Depreciation',
#   '_rowNm'): 'Expense.Acct.Exp.Depreciation',
#  ('IncomeStmt', 'Expense.Acct.Exp.Depreciation', 'acctType'): 'Expense',
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Depreciation',
#   'acct'): 'Acct.Exp.Depreciation',
#  ('IncomeStmt', 'Expense.Acct.Exp.Depreciation', 'acctSub'): '',
#  ('IncomeStmt', 'Expense.Acct.Exp.Depreciation', 'Debit'): 5246.06,
#  ('IncomeStmt', 'Expense.Acct.Exp.Depreciation', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Depreciation', 'Balance'): 5246.06,
#  ('IncomeStmt', 'Expense.Acct.Exp.Operating', '_lineNo'): 4,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Operating',
#   '_rowNm'): 'Expense.Acct.Exp.Operating',
#  ('IncomeStmt', 'Expense.Acct.Exp.Operating', 'acctType'): 'Expense',
#  ('IncomeStmt', 'Expense.Acct.Exp.Operating', 'acct'): 'Acct.Exp.Operating',
#  ('IncomeStmt', 'Expense.Acct.Exp.Operating', 'acctSub'): '',
#  ('IncomeStmt', 'Expense.Acct.Exp.Operating', 'Debit'): 235.34,
#  ('IncomeStmt', 'Expense.Acct.Exp.Operating', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Operating', 'Balance'): 235.34,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other', '_lineNo'): 5,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other', '_rowNm'): 'Expense.Acct.Exp.Other',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other', 'acctType'): 'Expense',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other', 'acct'): 'Acct.Exp.Other',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other', 'acctSub'): '',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other', 'Debit'): 387.11,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other', 'Credit'): 117.94,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other', 'Balance'): 269.17,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Celebration', '_lineNo'): 6,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Other.Celebration',
#   '_rowNm'): 'Expense.Acct.Exp.Other.Celebration',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Celebration', 'acctType'): 'Expense',
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Other.Celebration',
#   'acct'): 'Acct.Exp.Other',
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Other.Celebration',
#   'acctSub'): 'Celebration',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Celebration', 'Debit'): 65.36,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Celebration', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Celebration', 'Balance'): 65.36,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Const', '_lineNo'): 7,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Other.Const',
#   '_rowNm'): 'Expense.Acct.Exp.Other.Const',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Const', 'acctType'): 'Expense',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Const', 'acct'): 'Acct.Exp.Other',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Const', 'acctSub'): 'Const',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Const', 'Debit'): 73.96,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Const', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Const', 'Balance'): 73.96,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Plants', '_lineNo'): 8,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Other.Plants',
#   '_rowNm'): 'Expense.Acct.Exp.Other.Plants',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Plants', 'acctType'): 'Expense',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Plants', 'acct'): 'Acct.Exp.Other',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Plants', 'acctSub'): 'Plants',
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Plants', 'Debit'): 74.57,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Plants', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Other.Plants', 'Balance'): 74.57,
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Maintenance', '_lineNo'): 9,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Repair.Maintenance',
#   '_rowNm'): 'Expense.Acct.Exp.Repair.Maintenance',
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Maintenance', 'acctType'): 'Expense',
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Repair.Maintenance',
#   'acct'): 'Acct.Exp.Repair',
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Repair.Maintenance',
#   'acctSub'): 'Maintenance',
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Maintenance', 'Debit'): 135.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Maintenance', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Maintenance', 'Balance'): 135.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Repair', '_lineNo'): 10,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Repair.Repair',
#   '_rowNm'): 'Expense.Acct.Exp.Repair.Repair',
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Repair', 'acctType'): 'Expense',
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Repair', 'acct'): 'Acct.Exp.Repair',
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Repair', 'acctSub'): 'Repair',
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Repair', 'Debit'): 64.06,
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Repair', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Repair.Repair', 'Balance'): 64.06,
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Elec', '_lineNo'): 11,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Util.Elec',
#   '_rowNm'): 'Expense.Acct.Exp.Util.Elec',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Elec', 'acctType'): 'Expense',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Elec', 'acct'): 'Acct.Exp.Util',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Elec', 'acctSub'): 'Elec',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Elec', 'Debit'): 571.15,
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Elec', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Elec', 'Balance'): 571.15,
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Ins_Home', '_lineNo'): 12,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Util.Ins_Home',
#   '_rowNm'): 'Expense.Acct.Exp.Util.Ins_Home',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Ins_Home', 'acctType'): 'Expense',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Ins_Home', 'acct'): 'Acct.Exp.Util',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Ins_Home', 'acctSub'): 'Ins_Home',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Ins_Home', 'Debit'): 135.8,
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Ins_Home', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Ins_Home', 'Balance'): 135.8,
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Water', '_lineNo'): 13,
#  ('IncomeStmt',
#   'Expense.Acct.Exp.Util.Water',
#   '_rowNm'): 'Expense.Acct.Exp.Util.Water',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Water', 'acctType'): 'Expense',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Water', 'acct'): 'Acct.Exp.Util',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Water', 'acctSub'): 'Water',
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Water', 'Debit'): 300.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Water', 'Credit'): 0.0,
#  ('IncomeStmt', 'Expense.Acct.Exp.Util.Water', 'Balance'): 300.0,
#  ('IncomeStmt', 'TOTAL', '_lineNo'): 14,
#  ('IncomeStmt', 'TOTAL', '_rowNm'): 'TOTAL',
#  ('IncomeStmt', 'TOTAL', 'acctType'): 'TOTAL',
#  ('IncomeStmt', 'TOTAL', 'acct'): 'Net Income: -2,770.47',
#  ('IncomeStmt', 'TOTAL', 'acctSub'): '',
#  ('IncomeStmt', 'TOTAL', 'Debit'): 7288.94,
#  ('IncomeStmt', 'TOTAL', 'Credit'): 4518.47,
#  ('IncomeStmt', 'TOTAL', 'Balance'): -2770.47}

# %%
objIS.to_DF()
# Out:
#     _lineNo                               _rowNm acctType  \
# 0         1      Income.Acct.Rev.Fees.Other.Bank   Income
# 1         2     Income.Acct.Rev.Rent.Income.Rent   Income
# 2         3        Expense.Acct.Exp.Depreciation  Expense
# 3         4           Expense.Acct.Exp.Operating  Expense
# 4         5               Expense.Acct.Exp.Other  Expense
# 5         6   Expense.Acct.Exp.Other.Celebration  Expense
# 6         7         Expense.Acct.Exp.Other.Const  Expense
# 7         8        Expense.Acct.Exp.Other.Plants  Expense
# 8         9  Expense.Acct.Exp.Repair.Maintenance  Expense
# 9        10       Expense.Acct.Exp.Repair.Repair  Expense
# 10       11           Expense.Acct.Exp.Util.Elec  Expense
# 11       12       Expense.Acct.Exp.Util.Ins_Home  Expense
# 12       13          Expense.Acct.Exp.Util.Water  Expense
# 13       14                                TOTAL    TOTAL
#
#                      acct      acctSub    Debit   Credit  Balance
# 0     Acct.Rev.Fees.Other         Bank     0.53   400.53  -400.00
# 1           Acct.Rev.Rent  Income.Rent     0.00  4000.00 -4000.00
# 2   Acct.Exp.Depreciation               5246.06     0.00  5246.06
# 3      Acct.Exp.Operating                235.34     0.00   235.34
# 4          Acct.Exp.Other                387.11   117.94   269.17
# 5          Acct.Exp.Other  Celebration    65.36     0.00    65.36
# 6          Acct.Exp.Other        Const    73.96     0.00    73.96
# 7          Acct.Exp.Other       Plants    74.57     0.00    74.57
# 8         Acct.Exp.Repair  Maintenance   135.00     0.00   135.00
# 9         Acct.Exp.Repair       Repair    64.06     0.00    64.06
# 10          Acct.Exp.Util         Elec   571.15     0.00   571.15
# 11          Acct.Exp.Util     Ins_Home   135.80     0.00   135.80
# 12          Acct.Exp.Util        Water   300.00     0.00   300.00
# 13  Net Income: -2,770.47               7288.94  4518.47 -2770.47

# %%
objIS.

# %%
self = f1065
from typing import Dict, List, Optional, Tuple
import re
is_data = None
bs_data = None

# ── Step A: base dict — all fields, publish=False, value="" ───────
fillDict = self._defaultFill(nspaceDict)

# %%
# LLC GL data
import os
from pathlib import Path
import json
from ledger.LLC import LLC
from irs.pdfFill import pdfFill
from IPython.display import display, Markdown

# Link to LLC ledgers
top = Path.cwd().parents[2]
llcName = [f for f in os.listdir(top) if 'llcProfile' in f][0].replace('.json','').replace('llcProfile_','')
llc = LLC(llcName,debug=False, top=top)
# Save entity information
eDict = llc.entity
acctDIR = llc.acctDir() #os.path.join(llc.TOP, llc.dirAccounting, str(llc.yr))
yeDIR = llc.acctDir(dirName='ye')


# ----------   initialize IRS forms
from irs.irsForms import irsF1065, irsSchK1
           
fmSchK1 = irsSchK1(llc)
fm1065 = irsF1065(llc)

fm = fmSchK1

# %% [markdown]
# ## irsFormWorkFlow - form-IRS.pdf -> Form-keys.pdf
#
# #### Input:  Form-FieldNames.json
#
# - option: genFldNames=True| will generate (**replace**) Form-FieldNames.json

# %%
#irsFormWorkFlow - form-IRS.pdf -> Form-keys.pdf, using Form-FieldNames.json
def irsFormWorkFlow(fm, **kwargs):
    debug = kwargs.get('debug', False)

    
    
    display(Markdown(f"##### \n## Notebook using:\n### LLC: {llc.entity['entity_name']}\n\n### IRS Form: {fm.oID}"))
    inFN = fm.inFN()
    outFN = fm.outFN()
    keyFN = fm.keyFN()
    fldNmFN = fm.FN('FieldNames.json')
    print("<PDF IN     :", Path(inFN).name)
    print("<JSON FldNm :", Path(fldNmFN).name)
    print(">JSON Key   :", Path(outFN).name)
    print(">PDF OUT    :", Path(keyFN).name)
    
    
    ## Per Tax Year - Do once
    
    # Per Year, Save Form json field names, modify if any changes, json save per year
    # Do this once per year to reconcile new forms to IRS definitions.
    genFldNames = kwargs.get('genFldNames', False)
    if genFldNames: 
        if fm.oID == 'fmSchK1':
            from irs.irsFormFieldNames import irsSchKFields
            fm.fldNmSave(irsSchKFields().fldNmDict)
        elif fm.oID == 'irsF1065':
            from irs.irsFormFieldNames import irsF1065Fields
            fm1065.fldNmSave(irsF1065Fields().fldNmDict)
        print(f"Create key.json: {fm.oID}")
    
    ## Get Dict of all fields in form :: fm.genTestKeyDict()

    yeDIR = fm.llc.acctDir(to = 'ye')
    irsFormDir = os.path.join(yeDIR, 'Forms_IRS')
    
    #---- 1. Get form fields
    pf = pdfFill(inFN, outFN)
    fDict = pf.get()
    print(f"\nStep 1: Loaded form Field Name")
    if debug: 
        print(f"Sample fDict\n{list([(k,d) for k,d in testDict.items()])[0:3]}")
    
    # --- 2. Load Form map (json) : field index matches order offDict.keys()
    fldFN = fldNmFN
    fldNmDict = fm.fldNmLoad()
    # Load from py
    #fldNmDict = irsF1065Fields().fldNmDict
    print(f"\nStep 2: Load form Field Keys: key.fld:{len(fldNmDict)}/fm.fld{len(fDict)}, FILE: {fldFN}")
    if debug: 
        print(f"View fldNmDict\n{list([(k,d) for k,d in fldNmDict.items()])[0:3]}")
    
    # ---- 3. Create testDict to map field ID (F#) into every field
    #         OLD testDict = {k:self.pf._testKey(i,k,fDict[k]) for i,k in enumerate(fDict)}
    fldNmDict = fm.fldNmLoad()
    testDict =  {}
    for (i,k1),(j,k2) in zip(enumerate(fDict), enumerate(fldNmDict)):
        d = fDict[k1]
        d['field_id'] = k2
        testDict[k1] = d
    print(f"\nStep 3: Create Map: : testDict:{len(testDict)} -> keyNm:{len(fldNmDict)} x fm.fld:{len(fDict)}")
    if debug: 
        print(f"View testDict\n{list([(k,d) for k,d in testDict.items()])[0:3]}")
    
    
    # ---- 4. Output: PDF key.pdf  
    ts = pdfFill(inFN, outFN)
    oDict = ts.fillPDF(to = testDict, )
    print(f"\nStep 4: Create outPDF") 
    
    print(f"\n{fm.__class__.__name__} SUCC: testDict Generated {len(testDict)} Fields; \n-- FILE: {Path(keyFN)}")

irsFormWorkFlow(fm1065)  # genFldNames=True|False
print("\n\n", '*'*60, "\n\n")
irsFormWorkFlow(fmSchK1)  # genFldNames=True|False
# Out:
# #####
# ## Notebook using:
# ### LLC: W&B Group, LLC
#
# ### IRS Form: irsF1065
# <PDF IN     : Form_1065-IRS.pdf
# <JSON FldNm : Form_1065-FieldNames.json
# >JSON Key   : Form_1065-keys.pdf
# >PDF OUT    : Form_1065-keys.json
#
# Step 1: Loaded form Field Name
# Loading Form Field Name (json): Form_1065-FieldNames.json
# DIR: /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Form_1065-FieldNames.json
#
# Step 2: Load form Field Keys: key.fld:440/fm.fld440, FILE: /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Form_1065-FieldNames.json
# Loading Form Field Name (json): Form_1065-FieldNames.json
# DIR: /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Form_1065-FieldNames.json
#
# Step 3: Create Map: : testDict:440 -> keyNm:440 x fm.fld:440
#
# Step 4: Create outPDF
#
# irsF1065 SUCC: testDict Generated 440 Fields;
# -- FILE: /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Form_1065-keys.json
#
#
#  ************************************************************
# #####
# ## Notebook using:
# ### LLC: W&B Group, LLC
#
# ### IRS Form: irsSchK1
# <PDF IN     : Schedule_K_1-IRS.pdf
# <JSON FldNm : Schedule_K_1-FieldNames.json
# >JSON Key   : Schedule_K_1-keys.pdf
# >PDF OUT    : Schedule_K_1-keys.json
#
# Step 1: Loaded form Field Name
# Loading Form Field Name (json): Schedule_K_1-FieldNames.json
# DIR: /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Schedule_K_1-FieldNames.json
#
# Step 2: Load form Field Keys: key.fld:111/fm.fld111, FILE: /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Schedule_K_1-FieldNames.json
# Loading Form Field Name (json): Schedule_K_1-FieldNames.json
# DIR: /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Schedule_K_1-FieldNames.json
#
# Step 3: Create Map: : testDict:111 -> keyNm:111 x fm.fld:111
#
# Step 4: Create outPDF
#
# irsSchK1 SUCC: testDict Generated 111 Fields;
# -- FILE: /Users/frankrojas/GDrive/Family/Assets-Hobby/RealEstateInvestments/LLC-WB-Group/pages/AccountingData/2025/YE_Tax_Records/Forms_IRS/Schedule_K_1-keys.json

# %%
print(len(glDict), len(testDict))
d = {}
for (i,k1),(j,k2)  in  zip(enumerate(glDict), enumerate(testDict)):
    g = glDict[k1]
    fldDict = testDict[k2]
    f = fldDict['field_id']
    if f != g : 
        print("ERROR: glDict and fmDict have a mismatch")    
        print("--ERR>", i,j, glDict[k1], testDict[k2])
    v = '' if fldDict['type'] == 'text' else 'chk'
    d[k1] = v
list([(k,d) for k,d in d.items()])[0:3]
fn = fm.FN('glKeys.json')
print(fn)
with open(fn, 'w') as fio:
    json.dump(d, fio, indent=4)
