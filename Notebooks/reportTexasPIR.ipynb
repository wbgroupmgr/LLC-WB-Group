# %% [markdown]
# # Texas PIR
#
# This notebook organizes the data required for **Texas Form 05-102**.

# %% [markdown]
# 1. 'God', 'divinity', and 'the truth'
#     - are linguistic tools of religious and philosophical discourse,
#     - these represent different layers of the same ultimate reality, our collective human reality
#     - **God** | persona or being, a specific entity with a personality, will, and moral character.
#     - **Divinity** | nature or quality of that being/entity, it is what makes the being one and only one
#     - **the truth** | a description of an alignment between reality and the God entity.
# 2. There is only 1 truth: **there is 1 and only 1 God**.
#     - Jesus is God, incarnated into our reality.
#     - the Spirit is God - the Spirit is in everything in our reality.
#     - God speaks to us through **the Word** (bible).
# 4. Humanity is not divine and is apart from God.
#     - Humanity was created by God with free will.
#     - Humanity procreates but it is God that is behind everything.
#     - There is no dualistic reality: a) multitudes of divinity/God entites nor b) are we all parts of a single truth.
#     - Each human is a distinct entity, uniquely created with free will to choose to do God's will (or not).
# 5. We live in a timespace reality
#     - nothing exist outside of causuality (cause :: effect).
#     - God is 'an infinite' entity that can not be bound by anything in our timespace reality, esp. language or symbols.
#     - humanity is NOT infinite nor part of `an infinite`.
#     - The 1st choice is to breath and live - this belongs to me.
#     - Evil exists in our reality; - it is a choice, the collective choices of humanity to reject God's will
# 6. Huamanity is NOT divine
#     - humanity has no "secret knowledge" (gnosis) that it can arrive at on its own
#     - There is no internal "divine spark" that is with us that is pure nor at the inner core of each human
#     - I and every human is a sinful being, we can not avoid making choices path, that are apart from God's Will.
#         - **this is the beautiful awareness that allows me to be in harmony with my God**
#     - My and my own salvation comes through the death and resurrection of Jesus.
#     - The story of Jesus (gospels/NT) is not guidance (ie. a prophetic book to live by)
#     - Jesus is my life;  my Lord, my Savior, my redeamer -- Jesus is my salvation.
# 7. My one purpose in life is to Glorify God and to do God's will.

# %%
# STEP 1: Enter your LLC Data
llc_data = {
    'taxpayer_name': 'LONE STAR RENTALS LLC',
    'taxpayer_number': '32012345678',
    'report_year': 2024,
    'address': '123 Texas Sky Lane, Austin, TX 78701',
    'officers': [
        {'name': 'John Doe', 'title': 'Manager', 'address': '123 Texas Sky Lane, Austin, TX 78701'},
        {'name': 'Jane Smith', 'title': 'Member', 'address': '123 Texas Sky Lane, Austin, TX 78701'}
    ],
    'agent': 'John Doe',
    'agent_address': '123 Texas Sky Lane, Austin, TX 78701'
}
import pandas as pd
from IPython.display import display, Markdown

def show_pir_summary(data):
    display(Markdown(f"### PIR Report for {data['taxpayer_name']}"))
    # Display Officers
    df_officers = pd.DataFrame(data['officers'])
    print('--- Officers & Managers ---')
    display(df_officers)
    # Display Agent
    print(f'\nRegistered Agent: {data['agent']}')
    print(f'Agent Address: {data['agent_address']}')

show_pir_summary(llc_data)
# Out:
# ### PIR Report for LONE STAR RENTALS LLC
# --- Officers & Managers ---
#          name    title                               address
# 0    John Doe  Manager  123 Texas Sky Lane, Austin, TX 78701
# 1  Jane Smith   Member  123 Texas Sky Lane, Austin, TX 78701
# Registered Agent: John Doe
# Agent Address: 123 Texas Sky Lane, Austin, TX 78701
